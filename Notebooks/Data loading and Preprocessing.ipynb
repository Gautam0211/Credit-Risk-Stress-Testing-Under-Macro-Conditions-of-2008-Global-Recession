# %%
import snowflake.connector
import pandas as pd

conn = snowflake.connector.connect(
    user='Gautam0211',
    password='XXXXXX',
    account='XXXX',
    warehouse='CREDIT_RISK_WH',
    database='CREDIT_RISK_DB',
    schema='PUBLIC',
    passcode='959340'  
)

query = "SELECT * FROM ANALYTICAL_BASE_TABLE;"
df = pd.read_sql(query, conn)
conn.close()

print(f" Success! Master dataframe loaded. Shape: {df.shape}")
# Out:
# C:\Users\Hi\AppData\Local\Temp\ipykernel_26236\1857562799.py:15: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
#  Success! Master dataframe loaded. Shape: (150000, 42)

# %%
df.head()
# Out:
#    CREDIT_SCORE  FIRST_PAYMENT_DATE FIRST_TIME_BUYER  MATURITY_DATE      MSA  \
# 0           742              200802                N         203801  41500.0
# 1           734              200802                N         203801  33460.0
# 2           667              200802                N         203801  45300.0
# 3           725              200802                N         203801  47260.0
# 4           777              200802                N         203801  33340.0
#
#    MI_PERCENT  NUMBER_UNITS OCCUPANCY_STATUS  CLTV  DTI  ...  \
# 0           0             1                P    39   42  ...
# 1          12             1                I    85   35  ...
# 2          25             1                P    90   28  ...
# 3          25             1                I    86   48  ...
# 4           0             1                P    55   46  ...
#
#    ORIGINATION_YEAR  LOAN_LIFESPAN_MONTHS  TOTAL_ACTUAL_LOSS  \
# 0              2008                    33                0.0
# ...

# %%
# ============================================================================
# This locks in your data schemas and exact NaN structures with snappy compression
df.to_parquet('analytical_base_table_raw.parquet', engine='pyarrow', compression='snappy', index=False)

print(" SUCCESS: Master table securely written to 'analytical_base_table.parquet'!")
# Out:
#  SUCCESS: Master table securely written to 'analytical_base_table.parquet'!
